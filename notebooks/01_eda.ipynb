# %% [markdown]
# ## Exploratory Data Analysis
#
# In this notebook, we explore the dataset using statistical summaries and visualizations. The goal is to understand the data's structure, distributions, and relationships relevant to loan approval prediction.

# %% [markdown]
# ## 🔍 Basic Data Audit
#
# We inspect the dataset's size, column types, and completeness. This helps identify data quality issues such as missing values and formatting inconsistencies.

# %%
# Import Necessary Libraries and Load The Data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("data/train.csv")
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
# df Head
df.head()
# Out:
#    id  person_age  person_income   person_home_ownership  person_emp_length  \
# 0   0          37          35000   RENT                                 0.0
# 1   1          22          56000   OWN                                  6.0
# 2   2          29          28800   OWN                                  8.0
# 3   3          30          70000   RENT                                14.0
# 4   4          22          60000   RENT                                 2.0
#
#           loan_intent   loan_grade  loan_amnt  loan_int_rate  \
# 0   EDUCATION           B                6000          11.49
# 1   MEDICAL             C                4000          13.35
# 2   PERSONAL            A                6000           8.90
# 3   VENTURE             B               12000          11.11
# 4   MEDICAL             A                6000           6.92
#
#    loan_percent_income   cb_person_default_on_file  \
# 0                 0.17   N
# 1                 0.07   N
# 2                 0.21   N
# ...

# %%
# df Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58645 entries, 0 to 58644
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          58645 non-null  int64
#  1   person_age                  58645 non-null  int64
#  2   person_income               58645 non-null  int64
#  3   person_home_ownership       58645 non-null  object
#  4   person_emp_length           58645 non-null  float64
#  5   loan_intent                 58645 non-null  object
#  6   loan_grade                  58645 non-null  object
#  7   loan_amnt                   58645 non-null  int64
#  8   loan_int_rate               58645 non-null  float64
#  9   loan_percent_income         58645 non-null  float64
#  10  cb_person_default_on_file   58645 non-null  object
#  11  cb_person_cred_hist_length  58645 non-null  int64
#  12  loan_status                 58645 non-null  int64
# ...

# %% [markdown]
# ## 📊 Univariate Analysis
#
# We examine the distribution of individual features to detect skewness, rare categories, and potential outliers.

# %% [markdown]
# ### Categorical Features

# %%
# Person Home Ownership 
print(df['person_home_ownership'].value_counts())
sns.countplot(data=df, x='person_home_ownership')
plt.title('Person Home Ownership Countplot')
plt.show()
# Out:
# person_home_ownership
# RENT                     30594
# MORTGAGE                 24824
# OWN                       3138
# OTHER                       89
# Name: count, dtype: int64

# %%
# Loan Intent 
print(df['loan_intent'].value_counts())
sns.countplot(data=df, x='loan_intent')
plt.title('Loan Intent Countplot')
plt.show()
# Out:
# loan_intent
# EDUCATION            12271
# MEDICAL              10934
# PERSONAL             10016
# VENTURE              10011
# DEBTCONSOLIDATION     9133
# HOMEIMPROVEMENT       6280
# Name: count, dtype: int64

# %%
# Loan Grade
print(df['loan_grade'].value_counts())
sns.countplot(data=df, x='loan_grade')
plt.title('Loan Grade Countplot')
plt.show()
# Out:
# loan_grade
# A             20984
# B             20400
# C             11036
# D              5034
# E              1009
# F               149
# G                33
# Name: count, dtype: int64

# %%
# Credit Default Record
print(df['cb_person_default_on_file'].value_counts())
sns.countplot(data=df, x='cb_person_default_on_file')
plt.title('Credit Default Record Countplot')
plt.show()
# Out:
# cb_person_default_on_file
# N                            49943
# Y                             8702
# Name: count, dtype: int64

# %% [markdown]
# ### Numerical Features

# %%
# Person Age
print("Person Age Statistics:")
print(df['person_age'].describe())
sns.histplot(df['person_age'], kde=True)
plt.title('Person Age Distribution')
plt.show()
sns.boxplot(x=df['person_age'])
plt.title('Person Age Boxplot')
plt.show()
# Out:
# Person Age Statistics:
# count    58645.000000
# mean        27.550857
# std          6.033216
# min         20.000000
# 25%         23.000000
# 50%         26.000000
# 75%         30.000000
# max        123.000000
# Name: person_age, dtype: float64

# %%
# Person Income
print("Person income Statistics:")
print(df['person_income'].describe())
sns.histplot(df['person_income'], kde=True)
plt.title('Person income Distribution')
plt.show()
sns.boxplot(x=df['person_income'])
plt.title('Person income Boxplot')
plt.show()
# Out:
# Person income Statistics:
# count    5.864500e+04
# mean     6.404617e+04
# std      3.793111e+04
# min      4.200000e+03
# 25%      4.200000e+04
# 50%      5.800000e+04
# 75%      7.560000e+04
# max      1.900000e+06
# Name: person_income, dtype: float64

# %%
# Loan Amount
print("Loan Amount Statistics:")
print(df['loan_amnt'].describe())
sns.histplot(df['loan_amnt'], kde=True)
plt.title('Loan Amount Distribution')
plt.show()
sns.boxplot(x=df['loan_amnt'])
plt.title('Loan Amount Boxplot')
plt.show()
# Out:
# Loan Amount Statistics:
# count    58645.000000
# mean      9217.556518
# std       5563.807384
# min        500.000000
# 25%       5000.000000
# 50%       8000.000000
# 75%      12000.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64

# %%
# Loan Interest Rate
print("\nLoan Interest Rate Statistics:")
print(df['loan_int_rate'].describe())
sns.histplot(df['loan_int_rate'], kde=True)
plt.title('Loan Interest Rate Distribution')
plt.show()
sns.boxplot(x=df['loan_int_rate'])
plt.title('Loan Interest Rate Boxplot')
plt.show()
# Out:
# Loan Interest Rate Statistics:
# count    58645.000000
# mean        10.677874
# std          3.034697
# min          5.420000
# 25%          7.880000
# 50%         10.750000
# 75%         12.990000
# max         23.220000
# Name: loan_int_rate, dtype: float64

# %%
# Loan Percent Income
print("\nLoan Percent Income Statistics:")
print(df['loan_percent_income'].describe())
sns.histplot(df['loan_percent_income'], kde=True)
plt.title('Loan Percent Income Distribution')
plt.show()
sns.boxplot(x=df['loan_percent_income'])
plt.title('Loan Percent Income Boxplot')
plt.show()
# Out:
# Loan Percent Income Statistics:
# count    58645.000000
# mean         0.159238
# std          0.091692
# min          0.000000
# 25%          0.090000
# 50%          0.140000
# 75%          0.210000
# max          0.830000
# Name: loan_percent_income, dtype: float64

# %%
# Person Employment Length
print("\nPerson Employment Length Statistics:")
print(df['person_emp_length'].describe())
sns.histplot(df['person_emp_length'], kde=True)
plt.title('Employment Length Distribution')
plt.show()
sns.boxplot(x=df['person_emp_length'])
plt.title('Employment Length Boxplot')
plt.show()
# Out:
# Person Employment Length Statistics:
# count    58645.000000
# mean         4.701015
# std          3.959784
# min          0.000000
# 25%          2.000000
# 50%          4.000000
# 75%          7.000000
# max        123.000000
# Name: person_emp_length, dtype: float64

# %%
# Credit History Length
print("\nCredit History Length Statistics:")
print(df['cb_person_cred_hist_length'].describe())
sns.histplot(df['cb_person_cred_hist_length'], kde=True)
plt.title('Credit History Length Distribution')
plt.show()
sns.boxplot(x=df['cb_person_cred_hist_length'])
plt.title('Credit History Length Boxplot')
plt.show()
# Out:
# Credit History Length Statistics:
# count    58645.000000
# mean         5.813556
# std          4.029196
# min          2.000000
# 25%          3.000000
# 50%          4.000000
# 75%          8.000000
# max         30.000000
# Name: cb_person_cred_hist_length, dtype: float64

# %%
# Loan Status
print("Loan Status Counts:")
print(df['loan_status'].value_counts())
print("\nLoan Status Proportions:")
print(df['loan_status'].value_counts(normalize=True))
sns.countplot(x='loan_status', data=df)
plt.title('Loan Status Distribution')
plt.xlabel('Loan Approved')
plt.ylabel('Number of Applicants')
plt.show()
# Out:
# Loan Status Counts:
# loan_status
# 0    50295
# 1     8350
# Name: count, dtype: int64
#
# Loan Status Proportions:
# loan_status
# 0    0.857618
# 1    0.142382
# Name: proportion, dtype: float64

# %% [markdown]
# ## 🔗 Bivariate Analysis
#
# We explore how features relate to the target variable (`loan_status`) to detect potential predictors.

# %% [markdown]
# ### Categorical Features vs. Target

# %%
# Person Home Ownership 
sns.countplot(data=df, x='person_home_ownership', hue='loan_status')
plt.title('Person Home Ownership Countplot by Loan Status')
plt.show()
print("Loan approval rate by person home ownership:")
print(pd.crosstab(df['person_home_ownership'], df['loan_status'], normalize='index') * 100)
print("\n")
# Out:
# Loan approval rate by person home ownership:
# loan_status                    0          1
# person_home_ownership
# MORTGAGE               94.025943   5.974057
# OTHER                  83.146067  16.853933
# OWN                    98.629700   1.370300
# RENT                   77.744002  22.255998

# %%
# Loan Intent Analysis
sns.countplot(data=df, x='loan_intent', hue='loan_status')
plt.title('Loan Intent Countplot by Loan Status')
plt.show()
print("Loan approval rate by loan intent:")
print(pd.crosstab(df['loan_intent'], df['loan_status'], normalize='index') * 100)
print("\n")
# Out:
# Loan approval rate by loan intent:
# loan_status                0          1
# loan_intent
# DEBTCONSOLIDATION  81.068652  18.931348
# EDUCATION          89.226632  10.773368
# HOMEIMPROVEMENT    82.627389  17.372611
# MEDICAL            82.174867  17.825133
# PERSONAL           86.721246  13.278754
# VENTURE            90.720208   9.279792

# %%
# Loan Grade Analysis
sns.countplot(data=df, x='loan_grade', hue='loan_status')
plt.title('Loan Grade Countplot by Loan Status')
plt.show()
print("Loan approval rate by loan grade:")
print(pd.crosstab(df['loan_grade'], df['loan_status'], normalize='index') * 100)
print("\n")
# Out:
# Loan approval rate by loan grade:
# loan_status          0          1
# loan_grade
# A            95.081967   4.918033
# B            89.769608  10.230392
# C            86.462486  13.537514
# D            40.643623  59.356377
# E            37.462834  62.537166
# F            38.926174  61.073826
# G            18.181818  81.818182

# %%
# Default Record Analysis
sns.countplot(data=df, x='cb_person_default_on_file', hue='loan_status')
plt.title('Credit Default Record Countplot by Loan Status')
plt.show()
print("Loan approval rate by default record:")
print(pd.crosstab(df['cb_person_default_on_file'], df['loan_status'], normalize='index') * 100)
# Out:
# Loan approval rate by default record:
# loan_status                        0          1
# cb_person_default_on_file
# N                          88.488877  11.511123
# Y                          70.110319  29.889681

# %% [markdown]
# ### Numerical Features vs. Target

# %%
# Person Age vs Loan Status
sns.boxplot(x='loan_status', y='person_age', data=df)
plt.title('Person Age by Loan Status')
plt.show()

# %%
# Person Income vs Loan Status
sns.boxplot(x='loan_status', y='person_income', data=df)
plt.title('Person Income by Loan Status')
plt.show()

# %%
# Loan Amount vs Loan Status 
sns.boxplot(x='loan_status', y='loan_amnt', data=df)
plt.title('Loan Amount by Loan Status')
plt.show()

# %%
# Credit History Length vs Loan Status
sns.boxplot(x='loan_status', y='cb_person_cred_hist_length', data=df)
plt.title('Credit History Length by Loan Status')
plt.show()

# %%
# Employment Length vs Loan Status
sns.boxplot(x='loan_status', y='person_emp_length', data=df)
plt.title('Employment Length by Loan Status')
plt.show()

# %%
# Interest Rate vs Loan Status
sns.boxplot(x='loan_status', y='loan_int_rate', data=df)
plt.title('Interest Rate by Loan Status')
plt.show()

# %%
# Loan Percent Income vs Loan Status
sns.boxplot(x='loan_status', y='loan_percent_income', data=df)
plt.title('Loan Percent Income by Loan Status')
plt.show()

# %% [markdown]
# ## 📈 Group Statistics
#
# We group by the target variable and compute aggregated statistics (mean, median) across numerical features to identify patterns by class.

# %%
# Group Statistics
numerical_cols = [
    'person_age',
    'person_income',
    'person_emp_length',
    'loan_amnt',
    'loan_int_rate',
    'loan_percent_income',
    'cb_person_cred_hist_length'
]

df.groupby('loan_status')[numerical_cols].agg(['mean', 'median'])
# Out:
#             person_age        person_income          person_emp_length         \
#                   mean median          mean   median              mean median
# loan_status
# 0            27.553634   26.0  66672.867720  60000.0          4.863048    4.0
# 1            27.534132   26.0  48224.661796  44000.0          3.725030    3.0
#
#                 loan_amnt          loan_int_rate        loan_percent_income  \
#                      mean   median          mean median                mean
# loan_status
# 0             8888.883229   8000.0     10.258767  10.39            0.145105
# 1            11197.271856  10000.0     13.202305  13.79            0.244363
#
#                    cb_person_cred_hist_length
#             median                       mean median
# loan_status
# 0             0.13                   5.818531    4.0
# 1             0.25                   5.783593    4.0

# %% [markdown]
# ## 🧮 Correlation Statistics
#
# We compute the Pearson correlation matrix among numerical variables to identify multicollinearity and potential feature redundancy.

# %%
# Correlation Statistics

numerical_cols = [
    'person_age',
    'person_income',
    'person_emp_length',
    'loan_amnt',
    'loan_int_rate',
    'loan_percent_income',
    'cb_person_cred_hist_length',
    'loan_status'
]

corr_matrix = df[numerical_cols].corr(method='pearson')
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1,fmt=".2f",linewidths=0.5, mask=np.triu(corr_matrix))
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Interpretation and Insights
#
# This exploratory analysis revealed several key patterns relevant for predicting loan approvals, including:
#
# - **Home Ownership**: Renters faced the highest rejection rate (**22.3%**), while owners had the lowest (**1.4%**).
# - **Loan Grade**: Rejection rates rise steeply from grade A (**5%**) to grade G (**82%**).
# - **Default History**: Applicants with prior defaults were rejected **30%** of the time, compared to **11.5%** without defaults.
# - **Numerical Trends**: Rejected applicants tended to have lower income, shorter employment and credit history, and higher interest rates and loan-to-income ratios.
#
# These insights provide a strong foundation for building our predictive model.
